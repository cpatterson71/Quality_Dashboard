# %%
import pandas as pd
import numpy as np
import altair as alt
import xlwings as xl
import plotly.express as px
import datetime as dt
# Out:
# c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
file = 'Quality_System_Document_Use_This.xlsx'
wb1 = xl.Book(file)
sht = wb1.sheets[0]
temp = sht.range('A1:N1322')
temp = temp.options(pd.DataFrame, index=False).value
temp.head()
# Out:
#   Date Opened Change Control Client       Requester     Document Revision  \
# 0  2020-10-12          20001    LPI        Lee Chen  LPI-PRO-009      000
# 1  2020-10-12          20002    LPI        Lee Chen  LPI-SOP-311      000
# 2  2020-10-12          20003    LPI        Lee Chen  LPI-SOP-312      000
# 3  2020-10-13          20004    LPI        Lee Chen  LPI-SOP-304      001
# 4  2020-10-15          20005    LPI  Carl Patterson  LPI-SOP-409      001
#
#    Reviewer        Approver Change Type Impact Assessment Quality Event  \
# 0  Lee Chen  Carl Patterson          CD              None          None
# 1  Lee Chen  Carl Patterson         SOP              None          None
# 2  Lee Chen  Carl Patterson         SOP              None          None
# 3  Lee Chen  Carl Patterson         SOP              None          None
# 4  Lee Chen     Rachel Long         SOP              None          None
#
#           Date Closed   Days Open  Count
# 0  2020-10-13 00:00:00        1.0    1.0
# 1  2021-02-25 00:00:00      136.0    1.0
# 2  2020-11-03 00:00:00       22.0    1.0
# 3  2020-10-14 00:00:00        1.0    1.0
# 4  2020-10-15 00:00:00        0.0    1.0

# %%
temp = temp.loc[:, ['Date Opened', 'Change Control', 'Client', 'Requester', 'Document', 'Revision', 'Reviewer', 'Approver', 'Date Closed ', 'Days Open', 'Count']]
temp.head()
# Out:
#   Date Opened Change Control Client       Requester     Document Revision  \
# 0  2020-10-12          20001    LPI        Lee Chen  LPI-PRO-009      000
# 1  2020-10-12          20002    LPI        Lee Chen  LPI-SOP-311      000
# 2  2020-10-12          20003    LPI        Lee Chen  LPI-SOP-312      000
# 3  2020-10-13          20004    LPI        Lee Chen  LPI-SOP-304      001
# 4  2020-10-15          20005    LPI  Carl Patterson  LPI-SOP-409      001
#
#    Reviewer        Approver         Date Closed   Days Open  Count
# 0  Lee Chen  Carl Patterson  2020-10-13 00:00:00        1.0    1.0
# 1  Lee Chen  Carl Patterson  2021-02-25 00:00:00      136.0    1.0
# 2  Lee Chen  Carl Patterson  2020-11-03 00:00:00       22.0    1.0
# 3  Lee Chen  Carl Patterson  2020-10-14 00:00:00        1.0    1.0
# 4  Lee Chen     Rachel Long  2020-10-15 00:00:00        0.0    1.0

# %%
weeks = temp['Date Closed '].astype(str)
days = []
for week in weeks:
    days.append(week[:-9])
temp['Date Closed '] = days

temp.head()
# Out:
#   Date Opened Change Control Client       Requester     Document Revision  \
# 0  2020-10-12          20001    LPI        Lee Chen  LPI-PRO-009      000
# 1  2020-10-12          20002    LPI        Lee Chen  LPI-SOP-311      000
# 2  2020-10-12          20003    LPI        Lee Chen  LPI-SOP-312      000
# 3  2020-10-13          20004    LPI        Lee Chen  LPI-SOP-304      001
# 4  2020-10-15          20005    LPI  Carl Patterson  LPI-SOP-409      001
#
#    Reviewer        Approver Date Closed   Days Open  Count
# 0  Lee Chen  Carl Patterson   2020-10-13        1.0    1.0
# 1  Lee Chen  Carl Patterson   2021-02-25      136.0    1.0
# 2  Lee Chen  Carl Patterson   2020-11-03       22.0    1.0
# 3  Lee Chen  Carl Patterson   2020-10-14        1.0    1.0
# 4  Lee Chen     Rachel Long   2020-10-15        0.0    1.0

# %%
temp['Date Opened'] = temp['Date Opened'].dt.strftime('%m/%d/%Y')
temp.head()
# Out:
#   Date Opened Change Control Client       Requester     Document Revision  \
# 0  10/12/2020          20001    LPI        Lee Chen  LPI-PRO-009      000
# 1  10/12/2020          20002    LPI        Lee Chen  LPI-SOP-311      000
# 2  10/12/2020          20003    LPI        Lee Chen  LPI-SOP-312      000
# 3  10/13/2020          20004    LPI        Lee Chen  LPI-SOP-304      001
# 4  10/15/2020          20005    LPI  Carl Patterson  LPI-SOP-409      001
#
#    Reviewer        Approver Date Closed   Days Open  Count
# 0  Lee Chen  Carl Patterson   2020-10-13        1.0    1.0
# 1  Lee Chen  Carl Patterson   2021-02-25      136.0    1.0
# 2  Lee Chen  Carl Patterson   2020-11-03       22.0    1.0
# 3  Lee Chen  Carl Patterson   2020-10-14        1.0    1.0
# 4  Lee Chen     Rachel Long   2020-10-15        0.0    1.0

# %%
temp['Date Opened'] = temp['Date Opened'].astype('datetime64[ns]')
temp['Year'] = temp['Date Opened'].dt.strftime('%Y')
temp.head()
# Out:
#   Date Opened Change Control Client       Requester     Document Revision  \
# 0  2020-10-12          20001    LPI        Lee Chen  LPI-PRO-009      000
# 1  2020-10-12          20002    LPI        Lee Chen  LPI-SOP-311      000
# 2  2020-10-12          20003    LPI        Lee Chen  LPI-SOP-312      000
# 3  2020-10-13          20004    LPI        Lee Chen  LPI-SOP-304      001
# 4  2020-10-15          20005    LPI  Carl Patterson  LPI-SOP-409      001
#
#    Reviewer        Approver Date Closed   Days Open  Count  Year
# 0  Lee Chen  Carl Patterson   2020-10-13        1.0    1.0  2020
# 1  Lee Chen  Carl Patterson   2021-02-25      136.0    1.0  2020
# 2  Lee Chen  Carl Patterson   2020-11-03       22.0    1.0  2020
# 3  Lee Chen  Carl Patterson   2020-10-14        1.0    1.0  2020
# 4  Lee Chen     Rachel Long   2020-10-15        0.0    1.0  2020

# %%
temp['Days Open'] = temp['Days Open'].astype('float64')
temp['Year'] = temp['Year'].astype('object')
temp['Change Control'] = temp['Change Control'].astype('int64')
temp.to_csv('temp.csv', index=False)

# %%
Change_Year = temp.loc[:,['Year', 'Count']]
Change_Year.head()
# Out:
#    Year  Count
# 0  2020    1.0
# 1  2020    1.0
# 2  2020    1.0
# 3  2020    1.0
# 4  2020    1.0

# %%
Change_Year.to_csv('Change_Year.csv', index=True)

# %%
Total_Year = temp.groupby('Year').agg({ "Days Open": "mean"})
df = pd.DataFrame(Total_Year)
df.head()
# Out:
#       Days Open
# Year
# 2020   3.847458
# 2021   1.643766
# 2022   2.006042
# 2023   3.726636
# 2024   3.519608

# %%
df['Average Days Open'] = df['Days Open']
df.head()
# Out:
#       Days Open  Average Days Open
# Year
# 2020   3.847458           3.847458
# 2021   1.643766           1.643766
# 2022   2.006042           2.006042
# 2023   3.726636           3.726636
# 2024   3.519608           3.519608

# %%
df.to_csv('Avg Days Open.csv', index=True)

# %%
data = pd.read_csv('Avg Days Open.csv')
data.head()
# Out:
#    Year  Days Open  Average Days Open
# 0  2020   3.847458           3.847458
# 1  2021   1.643766           1.643766
# 2  2022   2.006042           2.006042
# 3  2023   3.726636           3.726636
# 4  2024   3.519608           3.519608

# %%
data = data.loc[:,['Year', 'Average Days Open']]
data.to_csv('Avg Days Open.csv', index=True)
data.head()
# Out:
#    Year  Average Days Open
# 0  2020           3.847458
# 1  2021           1.643766
# 2  2022           2.006042
# 3  2023           3.726636
# 4  2024           3.519608

# %%
Total_Year = temp.groupby('Year').agg({ "Count": "sum"})
df = pd.DataFrame(Total_Year)
df.to_csv('Number per Year.csv', index=True)
df.head()
# Out:
#       Count
# Year
# 2020   59.0
# 2021  393.0
# 2022  331.0
# 2023  428.0
# 2024  110.0

# %%
Open_CC = pd.read_csv('temp.csv')
open_cc=pd.DataFrame(Open_CC)
open_cc.head()
# Out:
#   Date Opened  Change Control Client       Requester     Document  Revision  \
# 0  2020-10-12           20001    LPI        Lee Chen  LPI-PRO-009       0.0
# 1  2020-10-12           20002    LPI        Lee Chen  LPI-SOP-311       0.0
# 2  2020-10-12           20003    LPI        Lee Chen  LPI-SOP-312       0.0
# 3  2020-10-13           20004    LPI        Lee Chen  LPI-SOP-304       1.0
# 4  2020-10-15           20005    LPI  Carl Patterson  LPI-SOP-409       1.0
#
#    Reviewer        Approver Date Closed   Days Open  Count  Year
# 0  Lee Chen  Carl Patterson   2020-10-13        1.0    1.0  2020
# 1  Lee Chen  Carl Patterson   2021-02-25      136.0    1.0  2020
# 2  Lee Chen  Carl Patterson   2020-11-03       22.0    1.0  2020
# 3  Lee Chen  Carl Patterson   2020-10-14        1.0    1.0  2020
# 4  Lee Chen     Rachel Long   2020-10-15        0.0    1.0  2020

# %%
open_cc = open_cc.loc[:,['Requester', 'Date Opened', 'Client', 'Document', 'Revision', 'Closed']]
open_cc.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 open_cc = open_cc.loc[:,['Requester', 'Date Opened', 'Client', 'Document', 'Revision', 'Closed']]
#       2 open_cc.head()
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Closed'] not in index"

# %%
open_cc = open_cc[open_cc['Closed'] == 'Open']
open_cc.to_csv('Open_Docs.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Closed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 open_cc = open_cc[open_cc['Closed'] == 'Open']
#       2 open_cc.to_csv('Open_Docs.csv', index=True)
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Closed'

# %%
temp3 = pd.read_csv('temp3.csv')
temp3 = pd.DataFrame(temp3)
open_oos = temp3.loc[:,['Date','Requester', 'Client Code:', 'LIR_Number', 'Test', 'Closed']]
open_oos = open_oos[open_oos['Closed'] == 'Open']
open_oos.to_csv('OOS_Open.csv', index=False)

# %%
file4 = 'Quality_System_Document_Use_This.xlsx'
wb4 = xl.Book(file4)
sht4 = wb4.sheets[2]
temp4 = sht4.range('A1:F191')
Open_Dev = temp4.options(pd.DataFrame, index=False).value
Open_Dev.head()
# Out:
#   Date Opened: Deviation #: Client #:                           Description  \
# 0   2020-11-02    Dev-20001  DVS-3329   Ethanol released without ID testing
# 1   2020-12-11    Dev-20002       N/A  Analyst not qualified to run ID test
# 2   2020-12-22    Dev-20003       N/A       BI ampoules not read within 48°
# 3   2020-11-24    Dev-20004       DAV         Appearance form not available
# 4   2021-01-19    Dev-21001       N/A   Materials from autoclave were burnd
#
#                 Closed         Requester:
# 0  2020-11-25 00:00:00        Rachel Long
# 1  2020-12-20 00:00:00         Charles Lo
# 2  2020-12-28 00:00:00     Carl Patterson
# 3  2020-12-04 00:00:00     Carl Patterson
# 4  2021-01-19 00:00:00  Michael Bresnahan

# %%
Total_Dev_Year = Open_Dev.groupby('Date Opened:').agg({ "Count": "sum"})
Total_Dev_Year.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Total_Dev_Year = Open_Dev.groupby('Date Opened:').agg({ "Count": "sum"})
#       2 Total_Dev_Year.head()
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File c:\Users\carlp\miniconda3\Lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Count'] do not exist"

# %%
Open_Dev = Open_Dev.loc[:,['Requester:','Date Opened:', 'Deviation #:', 'Client #:', 'Description', 'Closed']]
Open_Dev = Open_Dev[Open_Dev['Closed'] == 'Open']
Open_Dev.to_csv('Open_Dev.csv', index=False)

# %%
#get CAPA and Complaints information
file4 = 'Quality_System_Document_Use_This.xlsx'
wb4 = xl.Book(file4)
sht4 = wb4.sheets[1]
temp4 = sht4.range('A1:F191')
Open_CAPA = temp4.options(pd.DataFrame, index=False).value
Open_CAPA.head()

# %%
Open_CAPA = Open_CAPA.loc[:,['Date Opened', 'Personnel', 'CAPA', 'Description', 'Client', 'Closed']]
Open_CAPA = Open_CAPA[Open_CAPA['Closed'] == 'Open']
Open_CAPA.to_csv('Open_CAPA.csv', index=False)
Open_CAPA.head()

# %%
file4 = 'Quality_System_Document_Use_This.xlsx'
wb4 = xl.Book(file4)
sht4 = wb4.sheets[5]
temp4 = sht4.range('A1:F191')
Open_comp = temp4.options(pd.DataFrame, index=False).value
Open_comp.head()

# %%
Open_comp = Open_comp.loc[:,['Date Opened', 'Personnel', 'Complaint', 'Description', 'Client', 'Closed']]
Open_comp = Open_comp[Open_comp['Closed'] == 'Open']
Open_comp.to_csv('Open_comp.csv', index=False)
Open_comp.head()
