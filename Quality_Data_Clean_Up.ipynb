# %%
import pandas as pd
import numpy as np
import altair as alt
from st_aggrid import AgGrid
import os
import sys

# %%
file = '\\\LPISERVER\Project Group - QAQC\\LPI\\Quality_System_Document_Use_This.xlsx'
temp = pd.read_excel(file)
temp.head()
# Out:
#   Date Opened:  Change Control #: (CC-) Client      Requester:       Doc #:  \
# 0   2020-10-12                  20001.0    LPI        Lee Chen  LPI-PRO-009
# 1   2020-10-12                  20002.0    LPI        Lee Chen  LPI-SOP-311
# 2   2020-10-12                  20003.0    LPI        Lee Chen  LPI-SOP-312
# 3   2020-10-13                  20004.0    LPI        Lee Chen  LPI-SOP-304
# 4   2020-10-15                  20005.0    LPI  Carl Patterson  LPI-SOP-409
#
#    Revision:  Reviewer        Approver Change Type: Impact Assessment:  \
# 0        0.0  Lee Chen  Carl Patterson           CD                NaN
# 1        0.0  Lee Chen  Carl Patterson          SOP                NaN
# 2        0.0  Lee Chen  Carl Patterson          SOP                NaN
# 3        1.0  Lee Chen  Carl Patterson          SOP                NaN
# 4        1.0  Lee Chen     Rachel Long          SOP                NaN
#
#   Quality Event:         Date Closed:   Days Open  \
# ...
